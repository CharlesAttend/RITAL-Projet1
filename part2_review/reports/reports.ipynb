# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('../stats/stats.csv')
df
# Out:
#      Unnamed: 0.1  Unnamed: 0   variable       value         Algo configName
# 0               0         0.0          0    0.818548  Naïve Bayes      Test1
# 1               1         1.0          0    0.796078  Naïve Bayes      Test1
# 2               2         2.0          0    0.807157  Naïve Bayes      Test1
# 3               3         3.0          0  255.000000  Naïve Bayes      Test1
# 4               4         4.0          1    0.793651  Naïve Bayes      Test1
# ..            ...         ...        ...         ...          ...        ...
# 163            23         NaN  macro_auc    0.789535          SVM      Test2
# 164            24         NaN  micro_auc    0.789535          SVM      Test2
# 165            25         NaN  micro_auc    0.789535          SVM      Test2
# 166            26         NaN  micro_auc    0.789535          SVM      Test2
# 167            27         NaN  micro_auc    0.789535          SVM      Test2
#
# [168 rows x 6 columns]
